# %%
import pandas as pd

# %%
page2_ff_aum = pd.read_csv("asset_ff,aum.csv",index_col=0)

# %%
page2_ff_aum
# Out:
#                       분류        AUM  Fund_Flow  ff/aum  return_1w  return_1m
# 자산군
# 주식                    DM  8794660.5     7474.0    0.08       -0.1        2.7
# 주식                    EM   837185.9      911.3    0.11        1.4        3.5
# 주식                    US  4778500.5     7600.2    0.16       -0.2        1.8
# 주식                Europe   132887.7      599.9    0.45        0.6        5.7
# 주식                 Japan   596857.0     -447.9   -0.08       -2.0       -3.0
# 주식                 China   322770.6      -30.7   -0.01        2.0        2.7
# 주식                Taiwan    78183.3     1049.0    1.34       -0.5        0.4
# 주식                 Korea    10289.3       67.1    0.65        0.2        0.0
# 주식                 India    82968.2     -189.5   -0.23        0.5       -0.4
# 주식                Growth  1557213.8     2385.7    0.15        0.0        1.9
# 주식                 Value  1121731.3     1853.0    0.17        0.1        3.8
# ...

# %%
page2_ff_aum = page2_ff_aum[['분류','ff/aum','return_1w','AUM']]

# %%
page2_ff_aum.to_csv('./data/page2_ff,aum.csv')

# %%
file_path = './data/page2_ff,aum.csv'  # 실제 파일 경로로 변경 필요
df_page2 = pd.read_csv(file_path,index_col=0)

# %%
df_stocks = df_page2[df_page2.index == '주식']

# %%
df_stocks['대분류'] =['Country','Country','Country','Country','Country','Country','Country','Country','Country','Style','Style','Style','Style','Style','Sector','Sector','Sector','Sector','Sector','Sector','Sector','Sector','Sector','Sector']
# Out:
# C:\Users\20250003\AppData\Local\Temp\ipykernel_27320\2199822850.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_stocks['대분류'] =['Country','Country','Country','Country','Country','Country','Country','Country','Country','Style','Style','Style','Style','Style','Sector','Sector','Sector','Sector','Sector','Sector','Sector','Sector','Sector','Sector']

# %%
df_stocks = df_stocks[['대분류','분류','ff/aum','return_1w','AUM']]

# %%
df_page2
# Out:
#                       분류  ff/aum  return_1w        AUM
# 자산군
# 주식                    DM    0.09       -0.1  8794725.8
# 주식                    EM    0.09        1.4   837185.9
# 주식                    US    0.16       -0.2  4778489.4
# 주식                Europe    0.45        0.6   132887.7
# 주식                 Japan   -0.08       -2.0   596857.0
# 주식                 China   -0.06        2.0   322770.6
# 주식                Taiwan    1.34       -0.5    78183.3
# 주식                 Korea    0.65        0.2    10347.2
# 주식                 India   -0.23        0.5    82968.2
# 주식                Growth    0.15        0.0  1557231.4
# 주식                 Value    0.16        0.1  1121729.9
# 주식                 Large    0.14        0.1  7406947.0
# 주식                   Mid    0.22       -0.1   432031.1
# 주식                 Small   -0.15       -0.0   509478.9
# 주식         Communication    0.59        2.7    39159.3
# 주식         Discretionary   -0.08       -1.9    37742.8
# ...

# %%
# CSV 파일 불러오기
file_path = "./data/page2_ff,aum.csv"  # 실제 파일 경로로 변경 필요
df_page2 = pd.read_csv(file_path, index_col=0)

# 주식 데이터 필터링
df_commodity = df_page2[df_page2.index == '원자재']

df_commodity = df_commodity[['분류','ff/aum','return_1w','AUM']]

# %%
df_commodity
# Out:
#                     분류  ff/aum  return_1w       AUM
# 자산군
# 원자재        Diversified   -0.23        2.0   20495.3
# 원자재    Precious_metals    0.26        1.8  281464.0
# 원자재        Energy&Fuel   10.38       -2.1    1109.4
# 원자재  Industrial_metals   -0.43        2.8    1299.2
# 원자재        Agriculture    2.51        1.5     883.5

# %%
df_page2
# Out:
#                       분류  ff/aum  return_1w        AUM
# 자산군
# 주식                    DM    0.09       -0.1  8794725.8
# 주식                    EM    0.09        1.4   837185.9
# 주식                    US    0.16       -0.2  4778489.4
# 주식                Europe    0.45        0.6   132887.7
# 주식                 Japan   -0.08       -2.0   596857.0
# 주식                 China   -0.06        2.0   322770.6
# 주식                Taiwan    1.34       -0.5    78183.3
# 주식                 Korea    0.65        0.2    10347.2
# 주식                 India   -0.23        0.5    82968.2
# 주식                Growth    0.15        0.0  1557231.4
# 주식                 Value    0.16        0.1  1121729.9
# 주식                 Large    0.14        0.1  7406947.0
# 주식                   Mid    0.22       -0.1   432031.1
# 주식                 Small   -0.15       -0.0   509478.9
# 주식         Communication    0.59        2.7    39159.3
# 주식         Discretionary   -0.08       -1.9    37742.8
# ...

# %%
# CSV 파일 불러오기
file_path = "./data/page2_ff,aum.csv"  # 실제 파일 경로로 변경 필요
df_page2 = pd.read_csv(file_path, index_col=0)

# 주식 데이터 필터링
df_stocks = df_page2[df_page2.index == '채권']

df_stocks['대분류'] =['Segmentation','Segmentation','Segmentation','Segmentation','Segmentation','Segmentation','Segmentation','Credit Rating','Credit Rating','Credit Rating','Maturity','Maturity','Maturity']
df_stocks = df_stocks[['대분류','분류','ff/aum','return_1w','AUM']]
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7172\25103330.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_stocks['대분류'] =['Segmentation','Segmentation','Segmentation','Segmentation','Segmentation','Segmentation','Segmentation','Credit Rating','Credit Rating','Credit Rating','Maturity','Maturity','Maturity']
